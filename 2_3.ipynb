# %%
import torch

# %%
x = torch.tensor(3.0)
y = torch.tensor(2.0)

x+y, x-y, x/y, x**y
# Out:
# (tensor(5.), tensor(1.), tensor(1.5000), tensor(9.))

# %%
x = torch.arange(3, dtype = torch.float32)
x, x[2], len(x), x.shape

#order: the number of axes
#dimensionality: the number of componenets
# Out:
# (tensor([0., 1., 2.]), tensor(2.), 3, torch.Size([3]))

# %%
A = torch.arange(6).reshape(3, 2)
A, A.T
# Out:
# (tensor([[0, 1],
#          [2, 3],
#          [4, 5]]),
#  tensor([[0, 2, 4],
#          [1, 3, 5]]))

# %%
A = torch.arange(6, dtype=torch.float32).reshape(2, 3)
sum_A = A.sum(axis=1, keepdims=True)
A, A / sum_A
# Out:
# (tensor([[0., 1., 2.],
#          [3., 4., 5.]]),
#  tensor([[0.0000, 0.3333, 0.6667],
#          [0.2500, 0.3333, 0.4167]]))

# %%
A.cumsum(axis=0), A.cumsum(axis=1)
# Out:
# (tensor([[0., 1., 2.],
#          [3., 5., 7.]]),
#  tensor([[ 0.,  1.,  3.],
#          [ 3.,  7., 12.]]))

# %%
y = torch.ones(3, dtype=torch.float32)
x, y, torch.dot(x, y) == torch.sum(x*y)
# Out:
# (tensor([0., 1., 2.]), tensor([1., 1., 1.]), tensor(True))

# %%
A.shape, x.shape, torch.mv(A, x), A@x
# Out:
# (torch.Size([2, 3]), torch.Size([3]), tensor([ 5., 14.]), tensor([ 5., 14.]))

# %%
B = torch.ones(3, 4)
torch.mm(A, B), A@B
# Out:
# (tensor([[ 3.,  3.,  3.,  3.],
#          [12., 12., 12., 12.]]),
#  tensor([[ 3.,  3.,  3.,  3.],
#          [12., 12., 12., 12.]]))

# %%
u = torch.tensor([3.0, -4.0])
torch.norm(u), torch.abs(u).sum(), torch.norm(torch.ones((4, 9)))
# Out:
# (tensor(5.), tensor(7.), tensor(6.))

# %%
X=torch.arange(24).reshape(2, 3, 4)
len(X)
"""
 For a tensor X of arbitrary shape, does len(X) always correspond to the length of a certain axis of X? What is that axis?
---> first axis (axis 0)

"""
# Out:
# 2

# %%
# X / X.sum(axis=1)
# size가 안 맞ㅇ므
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-27-0a294f8d667a> in <cell line: 1>()
# ----> 1 X / X.sum(axis=1)
#
# RuntimeError: The size of tensor a (3) must match the size of tensor b (2) at non-singleton dimension 1
